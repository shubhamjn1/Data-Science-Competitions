# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import os as os
os.chdir('/media/shubham/3AA25FBFA25F7DF7/AV/blogs/svd/images')

# %%
from scipy import *
from pylab import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = imread("car.jpg")[:,:,0]
img.rehape
# Out:
# (1600, 2560)

# %%
import cv2
from skimage import io
io.imshow(cv2.resize(img,(256,200)))

# %%
gray()
figure(1)
imshow(img)
np.matrix(img)
# Out:
# matrix([[ 76,  76,  76, ...,  66,  67,  69],
#         [ 76,  76,  76, ...,  66,  68,  70],
#         [ 76,  76,  76, ...,  66,  69,  71],
#         ...,
#         [100, 100,  95, ...,  32,  35,  37],
#         [ 80,  95, 107, ..., 103, 105, 107],
#         [ 48,  49,  60, ..., 143, 153, 166]], dtype=uint8)

# %%
m,n = img.shape
U,S,V = svd(img)
S = resize(S,[m,1])*eye(m,n)

# %%
k=250
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[ 46.83741377,  44.32115938,  40.42681488, ...,  20.41198476,
#           22.69410048,  23.87274737],
#         [ 47.28323236,  44.94222335,  41.75925714, ...,  22.2253092 ,
#           24.6503578 ,  25.47461338],
#         [ 45.35933796,  43.41299308,  41.57945881, ...,  23.85876949,
#           26.00448191,  26.40706714],
#         ...,
#         [ 43.40003966,  52.06892966,  54.40429531, ..., -36.28588548,
#          -37.31105834, -30.94935002],
#         [ 43.91835633,  40.00691922,  41.44911859, ...,  39.38054366,
#           40.50732376,  42.37656931],
#         [ 13.70013273,  10.30643164,  18.90579429, ...,  80.07092598,
#           88.92444628,  92.40985108]])

# %%
k=100
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[ 45.29545412,  44.70339359,  42.87108346, ...,  15.95941799,
#           18.04070607,  20.66120048],
#         [ 45.08390898,  44.59839165,  43.12019769, ...,  17.01318742,
#           18.79948059,  20.89832074],
#         [ 45.00367944,  44.65683217,  43.65347645, ...,  18.7166187 ,
#           20.1452374 ,  21.41698613],
#         ...,
#         [ 42.4278159 ,  46.68493444,  43.34035805, ..., -11.54508213,
#           -4.89079268,   6.10778163],
#         [ 30.8661039 ,  30.74029701,  29.79548458, ...,  50.13045171,
#           56.47410075,  61.22582713],
#         [  7.31850256,   3.33916528,   2.58469135, ...,  75.07426328,
#           80.18280373,  82.37686491]])

# %%
k=50
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[  4.23281955e+01,   4.18341554e+01,   4.06140738e+01, ...,
#            2.15713415e+01,   2.14583366e+01,   1.97933026e+01],
#         [  4.28210449e+01,   4.24126637e+01,   4.14688513e+01, ...,
#            2.14696876e+01,   2.12376523e+01,   1.95168130e+01],
#         [  4.31435869e+01,   4.29332098e+01,   4.23163117e+01, ...,
#            2.14697321e+01,   2.12142049e+01,   1.93973907e+01],
#         ...,
#         [  3.46405248e+01,   3.49834678e+01,   3.10383948e+01, ...,
#           -2.96465810e-01,   7.41969092e+00,   1.80033569e+01],
#         [  2.05011393e+01,   2.02093415e+01,   1.73382714e+01, ...,
#            4.75132637e+01,   5.24862674e+01,   5.66058008e+01],
#         [  3.23533147e+00,   2.37113774e+00,  -4.70313039e-02, ...,
#            6.34582044e+01,   6.62207716e+01,   6.94576297e+01]])

# %%
k=30
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[ 46.89832179,  48.50699206,  48.48565249, ...,  16.30590851,
#           16.77354388,  17.43075703],
#         [ 47.18706829,  48.78401557,  48.84171349, ...,  16.1586731 ,
#           16.61207157,  17.30562751],
#         [ 47.62188647,  49.21284647,  49.35458925, ...,  16.01304166,
#           16.41382339,  17.06811676],
#         ...,
#         [ 10.39350536,  10.91951184,  10.73893328, ...,  34.22940334,
#           35.30247416,  37.50657413],
#         [  7.87602543,   8.89541016,   8.87597194, ...,  59.06689487,
#           59.84925625,  60.00152585],
#         [  3.52938805,   4.28585505,   4.07365964, ...,  64.82470943,
#           65.68654509,  66.77684217]])

# %%
k=20
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[ 43.93906171,  44.06681341,  44.02294974, ...,   3.47185818,
#            4.7217432 ,   5.69647777],
#         [ 44.46669631,  44.58315425,  44.57409114, ...,   3.68432161,
#            4.87922025,   5.88914155],
#         [ 44.98381339,  45.09965905,  45.13019567, ...,   3.93374721,
#            5.0684899 ,   6.09321894],
#         ...,
#         [  5.40892361,   6.21613798,   5.39421578, ...,  61.00904506,
#           59.59485173,  61.46904266],
#         [  6.19774622,   7.31260952,   6.88842871, ...,  69.44022407,
#           68.1864736 ,  68.53028351],
#         [  4.82261467,   6.18713514,   5.96970538, ...,  72.95920228,
#           71.46720701,  72.24987488]])

# %%
k=10
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[  3.49543966e+01,   3.43181566e+01,   3.44260870e+01, ...,
#            6.80779238e-01,   2.72750867e+00,   7.08873248e-02],
#         [  3.50515878e+01,   3.44056063e+01,   3.45101317e+01, ...,
#            5.78775988e-01,   2.63374210e+00,  -4.76151829e-02],
#         [  3.52459158e+01,   3.45952401e+01,   3.46982109e+01, ...,
#            5.04686885e-01,   2.56631562e+00,  -1.41374241e-01],
#         ...,
#         [ -1.84616460e+00,  -1.69164005e+00,  -1.62385074e+00, ...,
#            7.27491994e+01,   7.10292132e+01,   7.25381409e+01],
#         [ -1.31438457e+00,  -1.22657476e+00,  -1.16011650e+00, ...,
#            7.69455504e+01,   7.51615809e+01,   7.65208294e+01],
#         [ -2.55878492e+00,  -2.40939043e+00,  -2.36808238e+00, ...,
#            7.81141845e+01,   7.62111099e+01,   7.77416993e+01]])

# %%
k=3
figure(2)
imshow(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
show()
np.matrix(dot(U[:,1:k], dot(S[1:k,1:k],V[1:k,:])))
# Out:
# matrix([[ 5.54441533,  5.54929996,  5.5804496 , ...,  6.37296163,
#           6.43867278,  7.14924159],
#         [ 5.45904922,  5.46402667,  5.49522114, ...,  6.27479246,
#           6.33914112,  7.04598161],
#         [ 5.41694442,  5.42194741,  5.4531008 , ...,  6.22637842,
#           6.29009732,  6.99422986],
#         ...,
#         [ 5.61962812,  5.61130011,  5.60142931, ...,  6.46305752,
#           6.55737826,  6.70765723],
#         [ 5.10465745,  5.09584138,  5.08297009, ...,  5.8711401 ,
#           5.95942928,  6.04223453],
#         [ 5.07737253,  5.06799162,  5.05327923, ...,  5.83992616,
#           5.92902081,  5.98511833]])
